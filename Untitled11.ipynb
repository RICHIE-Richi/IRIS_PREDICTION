# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import datasets, linear_model
import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#k =["sepal length (cm)", "sepal width (cm)"]
x = "sepal length (cm)", "petal width (cm)"
y = "sepal length (cm)", "petal width (cm)"
plt.xlabel("sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.title('iris')
plt.plot(df)
plt.scatter(x, y)

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]>

# %%
sns.jointplot(data=df)

# %%
sns.lmplot(data=df, x="sepal length (cm)", y = "sepal width (cm)")

# %%
df.dropna()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
x=df["sepal length (cm)"].values
y=df["sepal width (cm)"].values

# %%
from sklearn.model_selection import train_test_split
x_train, y_train, x_test, y_test = train_test_split(x, y, test_size = 0.50, random_state = 40)

# %%
x_train
# Out:
# array([5.1, 6.7, 5.2, 6.4, 6.3, 6.7, 6.3, 6.7, 6. , 7.7, 4.9, 5.8, 6.3,
#        6.9, 5.5, 4.9, 5.1, 6.9, 5.8, 6.1, 5.5, 6. , 6.3, 7.2, 4.9, 5.9,
#        6. , 6.6, 6. , 5. , 5. , 5.6, 7.3, 5.7, 7.4, 4.5, 6.1, 6.2, 6.7,
#        5.5, 5.4, 6.7, 5.8, 5.4, 5.1, 4.9, 5. , 5. , 5.6, 6.3, 5.1, 5.1,
#        5. , 4.8, 6.9, 5.7, 7.9, 4.6, 6.5, 5.8, 5.8, 4.4, 6.9, 5. , 6.1,
#        6.1, 5.7, 6.4, 5.1, 5.8, 6.1, 4.8, 7. , 5. , 5.9])

# %%
y_train
# Out:
# array([4.4, 5.6, 6.4, 7.7, 5.5, 6.3, 6.2, 5.6, 5.4, 5.2, 5.5, 4.8, 5. ,
#        6.2, 5.7, 6.7, 6.3, 6.7, 6.8, 5.2, 6.4, 7.6, 5.5, 5.1, 5.6, 5.7,
#        4.3, 6.5, 4.9, 5.5, 6. , 5.1, 5. , 5.3, 4.7, 6.4, 4.6, 4.4, 5.7,
#        5.7, 4.6, 6.7, 6.1, 7.1, 7.2, 5.1, 7.7, 6. , 6.6, 4.9, 6.3, 6.5,
#        5.8, 6.2, 4.8, 5.4, 5.7, 5.6, 6.4, 6.3, 5. , 6.8, 5.9, 5.4, 6.8,
#        4.8, 4.7, 7.7, 4.6, 7.2, 6.5, 5.4, 6.5, 6.4, 5.2])

# %%
x_test
# Out:
# array([3.7, 3.1, 3.5, 3.1, 2.5, 3. , 3.3, 3. , 2.9, 3. , 3.1, 2.7, 2.5,
#        3.1, 4.2, 3. , 3.5, 3.2, 2.7, 2.9, 3.5, 3.4, 2.9, 3.6, 2.4, 3. ,
#        2.2, 2.9, 2.7, 3. , 2.3, 3. , 2.9, 3. , 2.8, 2.3, 2.6, 3.4, 3.1,
#        2.4, 3.9, 2.5, 2.7, 3.4, 2.5, 2.5, 3.2, 3.5, 2.8, 2.3, 3.8, 3.8,
#        2. , 3.1, 3.1, 2.8, 3.8, 3.6, 3. , 2.6, 4. , 2.9, 3.1, 3.3, 2.8,
#        3. , 2.8, 2.9, 3.8, 2.8, 2.8, 3. , 3.2, 3.4, 3.2])

# %%
y_test
# Out:
# array([3. , 3. , 3.2, 3.8, 2.5, 3.4, 2.2, 2.7, 3. , 3.4, 2.6, 3.4, 3.5,
#        2.8, 2.6, 3.3, 2.7, 3.3, 2.8, 2.7, 2.8, 3. , 2.3, 3.5, 2.9, 3.8,
#        3. , 3. , 3.1, 2.4, 2.2, 3.3, 3.4, 3.7, 3.2, 2.8, 3.4, 3.2, 2.5,
#        4.4, 3.1, 3.1, 3. , 3. , 3.2, 3.4, 2.6, 3. , 3. , 3.6, 3.3, 2.8,
#        2.7, 2.9, 3.4, 3.9, 2.9, 2.5, 2.7, 2.8, 3.6, 3.2, 3. , 3.7, 3. ,
#        3. , 3.2, 2.8, 3.2, 3. , 3.2, 3.4, 3. , 3.2, 4.1])

# %%
x_train = x_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)
x_test = x_test.reshape(-1,1)
y_train = y_train.reshape(-1,1)
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = reg.predict(x_test)
y_predict
# Out:
# array([[6.11362632],
#        [6.19301597],
#        [6.14008954],
#        [6.19301597],
#        [6.27240562],
#        [6.20624758],
#        [6.16655276],
#        [6.20624758],
#        [6.21947919],
#        [6.20624758],
#        [6.19301597],
#        [6.24594241],
#        [6.27240562],
#        [6.19301597],
#        [6.04746828],
#        [6.20624758],
#        [6.14008954],
#        [6.17978437],
#        [6.24594241],
#        [6.21947919],
#        [6.14008954],
#        [6.15332115],
#        [6.21947919],
#        [6.12685793],
#        [6.28563723],
#        [6.20624758],
#        [6.31210045],
#        [6.21947919],
#        [6.24594241],
#        [6.20624758],
#        [6.29886884],
#        [6.20624758],
#        [6.21947919],
#        [6.20624758],
#        [6.2327108 ],
#        [6.29886884],
#        [6.25917402],
#        [6.15332115],
#        [6.19301597],
#        [6.28563723],
#        [6.08716311],
#        [6.27240562],
#        [6.24594241],
#        [6.15332115],
#        [6.27240562],
#        [6.27240562],
#        [6.17978437],
#        [6.14008954],
#        [6.2327108 ],
#        [6.29886884],
#        [6.10039471],
#        [6.10039471],
#        [6.33856367],
#        [6.19301597],
#        [6.19301597],
#        [6.2327108 ],
#        [6.10039471],
#        [6.12685793],
#        [6.20624758],
#        [6.25917402],
#        [6.0739315 ],
#        [6.21947919],
#        [6.19301597],
#        [6.16655276],
#        [6.2327108 ],
#        [6.20624758],
#        [6.2327108 ],
#        [6.21947919],
#        [6.10039471],
#        [6.2327108 ],
#        [6.2327108 ],
#        [6.20624758],
#        [6.17978437],
#        [6.15332115],
#        [6.17978437]])

# %%
reg.score(x_train, y_train)*100
# Out:
# 1.525881027167808

# %%
reg.score(x_test, y_predict)*100
# Out:
# 100.0
